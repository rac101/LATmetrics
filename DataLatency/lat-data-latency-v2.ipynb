# %% [markdown]
# # Cumulative Histograms of LAT data latency times
#
# ### Robert Cameron, April 2016

# %%
from astropy.table import Table, Column
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import calendar
import time
import datetime as dt
# %matplotlib inline
plt.rc('figure', figsize = [12, 10])
plt.rc('font', size = 16)

# %%
s01 = 978307200
utc01 = time.gmtime(s01)
t01 = time.asctime(utc01)
s16 = s01 + (15*365.0 + 3)*86400.0
utc16 = time.gmtime(s16)
t16 = time.asctime(utc16)
t01, t16
# Out:
# ('Mon Jan  1 00:00:00 2001', 'Fri Jan  1 00:00:00 2016')

# %%
t0 = '2001-01-01'
b1 = '2016-01-01'
e1 = '2016-04-01'
b2 = '2015-01-01'
e2 = '2015-04-01'

dt0 = dt.datetime.strptime(t0,"%Y-%m-%d")
db1 = dt.datetime.strptime(b1,"%Y-%m-%d")
de1 = dt.datetime.strptime(e1,"%Y-%m-%d")
db2 = dt.datetime.strptime(b2,"%Y-%m-%d")
de2 = dt.datetime.strptime(e2,"%Y-%m-%d")
st0 = calendar.timegm(dt0.timetuple())
sb1 = calendar.timegm(db1.timetuple())
se1 = calendar.timegm(de1.timetuple())
sb2 = calendar.timegm(db2.timetuple())
se2 = calendar.timegm(de2.timetuple())

sst0 = time.mktime(dt0.timetuple())
ssb1 = time.mktime(db1.timetuple())
sse1 = time.mktime(de1.timetuple())
ssb2 = time.mktime(db2.timetuple())
sse2 = time.mktime(de2.timetuple())


sb1-st0, ssb1-sst0
# Out:
# (473299200, 473299200.0)

# %%
# read regular ASCII tabular files of data

file = "/Users/rac/Documents/GLAST/ISOC/LATmetrics/latency/2016/all.runs.20160424"
f = Table.read(file, format = 'ascii')

# %%
types = ['NASA','SLAC','Total']
type = types[2]

t1 = f1[type]
lt1 = np.log10(t1)
t2 = f2[type]
lt2 = np.log10(t2)
t3 = f3[type]
lt3 = np.log10(t3)

# %%
n_bins = 100
#n, bins, patches = plt.hist(lt1, n_bins, normed=1, histtype='step', cumulative=True)
plt.hist(lt1, n_bins, normed=1, histtype='step', cumulative=True, color=c1, label=lab1)
plt.hist(lt2, n_bins, normed=1, histtype='step', cumulative=True, color=c2, label=lab2)

plt.grid(True)
plt.ylim(0, 1.05)
plt.title('Run Processing Time (hours): '+type)
plt.legend(loc='upper left')

plt.show()

# %%
plt.xscale("log")
plt.hist(t1, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab1, color=c1)
plt.hist(t2, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab2, color=c2)
plt.legend(loc='lower right')
plt.ylim(0, 1.05)
plt.yticks( np.arange(21)/20 )
plt.grid(b=True, which='both', color='0.65',linestyle='-')
plt.title('Run Processing Time (hours): '+type)
plt.ylabel('Normalized Cumulative Distribution')
plt.show()

# %%
plt.xscale("log")
plt.hist(t3, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab3, color=c3)
plt.hist(t1, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab1, color=c1)
plt.hist(t2, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab2, color=c2)

plt.legend(loc='lower right')
plt.ylim(0, 1.05)
plt.yticks( np.arange(21)/20 )
plt.grid(b=True, which='both', color='0.65',linestyle='-')
plt.title('Run Processing Time (hours): '+type)
plt.ylabel('Normalized Cumulative Distribution')
plt.show()

# %%
plt.xscale("log")
plt.hist(t3, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab3, color=c3)
plt.hist(t2, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab2, color=c2)

plt.legend(loc='lower right')
plt.ylim(0, 1.05)
plt.yticks( np.arange(21)/20 )
plt.grid(b=True, which='both', color='0.65',linestyle='-')
plt.title('Run Processing Time (hours): '+type)
plt.ylabel('Normalized Cumulative Distribution')
plt.show()
