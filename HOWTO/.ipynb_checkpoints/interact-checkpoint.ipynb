# %% [markdown]
# from:
#        https://github.com/ipython/ipython/blob/master/examples/Interactive%20Widgets/Using%20Interact.ipynb

# %% [markdown]
# from IPython.html.widgets import *
# from IPython.display import *
# %matplotlib inline
# import matplotlib.pyplot as plt
# import numpy as np

# %%
...
plt?
...
# Out:
# Ellipsis

# %%
fig, ax = plt.subplots()
ax.plot([3,1,2,4,0,5,3,2,0,2,4],"o")
plt.close(fig)

vline = ax.axvline(1)
hline = ax.axhline(0.5)

def set_cursor(x, y):
    vline.set_xdata((x, x))
    hline.set_ydata((y, y))
    display(fig)

interact(set_cursor, x=(1, 9, 0.01), y=(0, 5, 0.01))

# %%
interact(r, foo=(0,10,0.1))
r=FloatText(
    value=foo,
    description='slider:',
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e973a0670f18> in <module>()
# ----> 1 interact(r, foo=(0,10,0.1))
#       2 r=FloatText(
#       3     value=foo,
#       4     description='slider:',
#       5 )
#
# /Users/rc/anaconda/lib/python3.4/site-packages/IPython/html/widgets/interaction.py in interact(__interact_f, **kwargs)
#     308         #        ...
#     309         f = __interact_f
# --> 310         w = interactive(f, **kwargs)
#     311         try:
#     312             f.widget = w
#
# /Users/rc/anaconda/lib/python3.4/site-packages/IPython/html/widgets/interaction.py in interactive(__interact_f, **kwargs)
#     188     kwargs = kwargs.copy()
#     189
# --> 190     new_kwargs = _find_abbreviations(f, kwargs)
#     191     # Before we proceed, let's make sure that the user has passed a set of args+kwargs
#     192     # that will lead to a valid call of the function. This protects against unspecified
#
# /Users/rc/anaconda/lib/python3.4/site-packages/IPython/html/widgets/interaction.py in _find_abbreviations(f, kwargs)
#     142     """Find the abbreviations for a function and kwargs passed to interact."""
#     143     new_kwargs = []
# --> 144     for param in signature(f).parameters.values():
#     145         for name, value, default in _yield_abbreviations_for_parameter(param, kwargs):
#     146             if value is empty:
#
# /Users/rc/anaconda/lib/python3.4/inspect.py in signature(obj)
#    2053 def signature(obj):
#    2054     '''Get a signature object for the passed callable.'''
# -> 2055     return _signature_internal(obj)
#    2056
#    2057
#
# /Users/rc/anaconda/lib/python3.4/inspect.py in _signature_internal(obj, follow_wrapper_chains, skip_bound_arg)
#    1896
#    1897     if not callable(obj):
# -> 1898         raise TypeError('{!r} is not a callable object'.format(obj))
#    1899
#    1900     if isinstance(obj, types.MethodType):
#
# TypeError: <IPython.html.widgets.widget_float.FloatText object at 0x106a63e48> is not a callable object

# %%
x = np.linspace(0, 40, 200)
y = np.sin(x)*5

fig, ax = plt.subplots()
ax.plot(x,y,".-")
plt.close(fig)

vline = ax.axvline(1)
hline = ax.axhline(0.5)

def set_cursor(x, y):
    vline.set_xdata((x, x))
    hline.set_ydata((y, y))
    display(fig)

interact(set_cursor, x=(1, 19, 0.01), y=(0, 5, 0.01))
# Out:
# <function __main__.set_cursor>

# %%
x = np.linspace(0, 40, 100)
y = np.sin(x)*5

def set_range(imin, imax):
    plt.ylim(-6, 6)
    plt.xlim(-10, 50)
    plt.plot(x[imin:imax], y[imin:imax], '.-')
    plt.title('Min='+str(imin)+'     Max='+str(imax))
#set_range(0,100)
interact(set_range, imin=(0, 20), imax=(80, 100))

# %%
@interact(x=(0.0,20.0,0.5))
def h(x=5.5):
    print(x)
# Out:
# 7.0

# %%
x = np.linspace(0, 40, 200)
y = np.sin(x)*5

fig, ax = plt.subplots()
ax.plot(x,y,".-")
plt.close(fig)

vline = ax.axvline(1)

def set_cursor(idx,xx,yy):
    vline.set_xdata((x[idx], x[idx]))
    display(fig)
    xx = x[idx]
    yy = y[idx]
    return xx, yy

interact(set_cursor, x=(1, 19, 0.01))
# Out:
# <function __main__.set_cursor>

# %%
@interact
def f(n=(0,10), x=TextWidget('hi')):
    print (n, x)
# Out:
# 2 hi
