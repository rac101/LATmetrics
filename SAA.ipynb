# %% [markdown]
# #SAA polygon analysis

# %%
import numpy as np
from astropy.io import fits
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
hdulist = fits.open('/Users/rc/Documents/data/SAA/tkrlrs/2015/tlrsimg2015.fits')
hdulist.info()
# Out:
# Filename: /Users/rc/Documents/data/SAA/tkrlrs/2015/tlrsimg2015.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      26   (361, 53, 65, 2)   float32

# %%
im4data = hdulist[0].data
im4data.shape
# Out:
# (2, 65, 53, 361)

# %%
countimg = im4data[1,0,:,:]

# %%
countimg.shape
# Out:
# (53, 361)

# %%
print (countimg[:,0])
# Out:
# [  85.  244.  126.  110.   72.   92.   69.   66.   68.   61.   62.   45.
#    69.   46.   62.   42.   68.   39.   53.   58.   28.   51.   58.   38.
#    44.   61.   46.   39.   47.   64.   40.   43.   56.   44.   46.   66.
#    38.   64.   44.   65.   45.   67.   60.   47.   64.   69.   88.   68.
#    96.  100.  142.  252.   75.]

# %%
fig = plt.figure(figsize=(18.0,18.0))
plt.imshow(countimg, origin='lower', cmap=plt.cm.hot)
#plt.colorbar()

# %%
saaavgimg = im4data[0,0,:,:]
saaavgimg.shape
# Out:
# (53, 361)

# %%
fig = plt.figure(figsize=(18.0,18.0))
plt.imshow(saaavgimg, origin='lower', cmap=plt.cm.hot)
