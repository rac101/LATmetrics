# %% [markdown]
# # Animation - Multi-Plot
#
# ### from Stackoverflow

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

x = np.arange(0, 2*np.pi, 0.1)
y = np.sin(x)

fig, axes = plt.subplots(ncols=2)

styles = ['r-', 'g+']
def plot(ax, style):
    return ax.plot(x, y, style, animated=True)[0]
lines = [plot(ax, style) for ax, style in zip(axes, styles)]
line.set_ydata(np.sin(j*x + 1/10.0))

#def animate(i):
#    for j, line in enumerate(lines, start=1):
#        line.set_ydata(np.sin(j*x + i/10.0))
#    return lines

# We'd normally specify a reasonable "interval" here...
#ani = animation.FuncAnimation(fig, animate, range(1, 200), interval=0, blit=True)
#ani = animation.FuncAnimation(fig, animate, range(1, 200), interval=10)
plt.show()
# Out:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     245                 self.gridline.draw(renderer)
#     246             if self.tick1On:
# --> 247                 self.tick1line.draw(renderer)
#     248             if self.tick2On:
#     249                 self.tick2line.draw(renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     759                 gc.restore()
#     760
# --> 761         if self._marker:
#     762             gc = renderer.new_gc()
#     763             self._set_gc_clip(gc)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/markers.py in __bool__(self)
#     194
#     195     if six.PY3:
# --> 196         def __bool__(self):
#     197             return bool(len(self._path.vertices))
#     198     else:
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     247                 self.tick1line.draw(renderer)
#     248             if self.tick2On:
# --> 249                 self.tick2line.draw(renderer)
#     250
#     251         if self.label1On:
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     780             marker = self._marker
#     781             tpath, affine = transf_path.get_transformed_points_and_affine()
# --> 782             if len(tpath.vertices):
#     783                 # subsample the markers if markevery is not None
#     784                 markevery = self.get_markevery()
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     247                 self.tick1line.draw(renderer)
#     248             if self.tick2On:
# --> 249                 self.tick2line.draw(renderer)
#     250
#     251         if self.label1On:
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     779
#     780             marker = self._marker
# --> 781             tpath, affine = transf_path.get_transformed_points_and_affine()
#     782             if len(tpath.vertices):
#     783                 # subsample the markers if markevery is not None
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in get_transformed_points_and_affine(self)
#    2700         be performed.
#    2701         """
# -> 2702         self._revalidate()
#    2703         return self._transformed_points, self.get_affine()
#    2704
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in _revalidate(self)
#    2689                     None,
#    2690                     {'interpolation_steps': self._path._interpolation_steps,
# -> 2691                      'should_simplify': self._path.should_simplify})
#    2692         self._invalid = 0
#    2693
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/path.py in _fast_from_codes_and_verts(cls, verts, codes, internals)
#     187         """
#     188         internals = internals or {}
# --> 189         pth = cls.__new__(cls)
#     190         if ma.isMaskedArray(verts):
#     191             verts = verts.astype(np.float_).filled(np.nan)
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     250
#     251         if self.label1On:
# --> 252             self.label1.draw(renderer)
#     253         if self.label2On:
#     254             self.label2.draw(renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/text.py in draw(self, renderer)
#     756             if not np.isfinite(posx) or not np.isfinite(posy):
#     757                 raise ValueError("posx and posy should be finite values")
# --> 758             posx, posy = trans.transform_point((posx, posy))
#     759             canvasw, canvash = renderer.get_canvas_width_height()
#     760
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in transform_point(self, point)
#    1399             msg = "The length of 'point' must be 'self.input_dims'"
#    1400             raise ValueError(msg)
# -> 1401         return self.transform(np.asarray([point]))[0]
#    1402
#    1403     def transform_path(self, path):
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in transform(self, values)
#    1305         values = np.asanyarray(values)
#    1306         ndim = values.ndim
# -> 1307         values = values.reshape((-1, self.input_dims))
#    1308
#    1309         # Transform the values
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1104         renderer.open_group(__name__)
#    1105
# -> 1106         ticks_to_draw = self._update_ticks(renderer)
#    1107         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1108                                                                 renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1040             tick.update_position(loc)
#    1041             tick.set_label1(label)
# -> 1042             tick.set_label2(label)
#    1043             ticks_to_draw.append(tick)
#    1044
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in set_label2(self, s)
#     275         """
#     276         self.label2.set_text(s)
# --> 277         self.stale = True
#     278
#     279     def _set_artist_props(self, a):
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in stale(self, val)
#     264             return
#     265
# --> 266         if val and self.stale_callback is not None:
#     267             self.stale_callback(self, val)
#     268
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1104         renderer.open_group(__name__)
#    1105
# -> 1106         ticks_to_draw = self._update_ticks(renderer)
#    1107         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1108                                                                 renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1028                     ds2 = 0.0
#    1029                 if np.isnan(ds2):
# -> 1030                     ds2 = 0.0
#    1031             interval_expanded = (interval_expanded[0] - ds1,
#    1032                                  interval_expanded[1] + ds2)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py in __exit__(self, *exc_info)
#    2873
#    2874     def __exit__(self, *exc_info):
# -> 2875         seterr(**self.oldstate)
#    2876         if self.call is not _Unspecified:
#    2877             seterrcall(self.oldcall)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py in seterr(all, divide, over, under, invalid)
#    2572
#    2573     pyvals[1] = maskvalue
# -> 2574     umath.seterrobj(pyvals)
#    2575     return old
#    2576
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     250
#     251         if self.label1On:
# --> 252             self.label1.draw(renderer)
#     253         if self.label2On:
#     254             self.label2.draw(renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/text.py in draw(self, renderer)
#     798         gc.restore()
#     799         renderer.close_group('text')
# --> 800         self.stale = False
#     801
#     802     def get_color(self):
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     245                 self.gridline.draw(renderer)
#     246             if self.tick1On:
# --> 247                 self.tick1line.draw(renderer)
#     248             if self.tick2On:
#     249                 self.tick2line.draw(renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     793                     snap = renderer.points_to_pixels(self._markersize) >= snap
#     794                 gc.set_snap(snap)
# --> 795                 gc.set_joinstyle(marker.get_joinstyle())
#     796                 gc.set_capstyle(marker.get_capstyle())
#     797                 marker_path = marker.get_path()
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      57
#      58     # the axes class has a second argument inframe for its draw method.
# ---> 59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
#      61         draw(artist, renderer, *args, **kwargs)
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     245                 self.gridline.draw(renderer)
#     246             if self.tick1On:
# --> 247                 self.tick1line.draw(renderer)
#     248             if self.tick2On:
#     249                 self.tick2line.draw(renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     769                 gc.set_foreground(rgbaFace, isRGBA=True)
#     770             else:
# --> 771                 gc.set_foreground(edgecolor)
#     772                 gc.set_linewidth(self._markeredgewidth)
#     773                 mec = self._markeredgecolor
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/backends/backend_macosx.py in set_foreground(self, fg, isRGBA)
#     209         _macosx.GraphicsContext.set_foreground(self, rgb)
#     210
# --> 211     def set_foreground(self, fg, isRGBA=False):
#     212         GraphicsContextBase.set_foreground(self, fg, isRGBA)
#     213         rgb = self.get_rgb()
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2281         # will draw the edges
#    2282         if self.axison and self._frameon:
# -> 2283             self.patch.draw(renderer)
#    2284
#    2285         if _do_composite:
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/patches.py in draw(self, renderer)
#     514
#     515         path = self.get_path()
# --> 516         transform = self.get_transform()
#     517         tpath = transform.transform_path_non_affine(path)
#     518         affine = transform.get_affine()
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/patches.py in get_transform(self)
#     195         to the :class:`Patch`.
#     196         """
# --> 197         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     198
#     199     def get_data_transform(self):
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/patches.py in get_patch_transform(self)
#     670
#     671     def get_patch_transform(self):
# --> 672         self._update_patch_transform()
#     673         return self._rect_transform
#     674
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/patches.py in _update_patch_transform(self)
#     666         rot_trans = transforms.Affine2D()
#     667         rot_trans.rotate_deg_around(x, y, self._angle)
# --> 668         self._rect_transform = transforms.BboxTransformTo(bbox)
#     669         self._rect_transform += rot_trans
#     670
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in __init__(self, boxout, **kwargs)
#    2536         Affine2DBase.__init__(self, **kwargs)
#    2537         self._boxout = boxout
# -> 2538         self.set_children(boxout)
#    2539         self._mtx = None
#    2540         self._inverted = None
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in set_children(self, *children)
#     168         """
#     169         for child in children:
# --> 170             child._parents[id(self)] = self
#     171
#     172     if DEBUG:
#
# /Users/rac/anaconda/lib/python3.5/weakref.py in __setitem__(self, key, value)
#     156         if self._pending_removals:
#     157             self._commit_removals()
# --> 158         self.data[key] = KeyedRef(value, self._remove, key)
#     159
#     160     def copy(self):
#
# /Users/rac/anaconda/lib/python3.5/weakref.py in __init__(self, ob, callback, key)
#     309
#     310     def __init__(self, ob, callback, key):
# --> 311         super().__init__(ob, callback)
#     312
#     313
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1104         renderer.open_group(__name__)
#    1105
# -> 1106         ticks_to_draw = self._update_ticks(renderer)
#    1107         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1108                                                                 renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1040             tick.update_position(loc)
#    1041             tick.set_label1(label)
# -> 1042             tick.set_label2(label)
#    1043             ticks_to_draw.append(tick)
#    1044
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in set_label2(self, s)
#     274         ACCEPTS: str
#     275         """
# --> 276         self.label2.set_text(s)
#     277         self.stale = True
#     278
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     245                 self.gridline.draw(renderer)
#     246             if self.tick1On:
# --> 247                 self.tick1line.draw(renderer)
#     248             if self.tick2On:
#     249                 self.tick2line.draw(renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     800                 if marker.get_marker() != ',':
#     801                     # Don't scale for pixels, and don't stroke them
# --> 802                     marker_trans = marker_trans.scale(w)
#     803                 else:
#     804                     gc.set_linewidth(0)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in scale(self, sx, sy)
#    1963         scale_mtx = np.array(
#    1964             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]],
# -> 1965             np.float_)
#    1966         self._mtx = np.dot(scale_mtx, self._mtx)
#    1967         self.invalidate()
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     247                 self.tick1line.draw(renderer)
#     248             if self.tick2On:
# --> 249                 self.tick2line.draw(renderer)
#     250
#     251         if self.label1On:
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     798                 marker_trans = marker.get_transform()
#     799                 w = renderer.points_to_pixels(self._markersize)
# --> 800                 if marker.get_marker() != ',':
#     801                     # Don't scale for pixels, and don't stroke them
#     802                     marker_trans = marker_trans.scale(w)
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     247                 self.tick1line.draw(renderer)
#     248             if self.tick2On:
# --> 249                 self.tick2line.draw(renderer)
#     250
#     251         if self.label1On:
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     762             gc = renderer.new_gc()
#     763             self._set_gc_clip(gc)
# --> 764             rgbaFace = self._get_rgba_face()
#     765             rgbaFaceAlt = self._get_rgba_face(alt=True)
#     766             edgecolor = self.get_markeredgecolor()
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in _get_rgba_face(self, alt)
#    1245             rgbaFace = None
#    1246         else:
# -> 1247             rgbaFace = colorConverter.to_rgba(facecolor, self._alpha)
#    1248         return rgbaFace
#    1249
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/colors.py in to_rgba(self, arg, alpha)
#     368                             'length of rgba sequence should be either 3 or 4')
#     369             else:
# --> 370                 r, g, b = self.to_rgb(arg)
#     371             if alpha is None:
#     372                 alpha = 1.0
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/colors.py in to_rgb(self, arg)
#     281
#     282         try:
# --> 283             return self.cache[arg]
#     284         except KeyError:
#     285             pass
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     250
#     251         if self.label1On:
# --> 252             self.label1.draw(renderer)
#     253         if self.label2On:
#     254             self.label2.draw(renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/text.py in draw(self, renderer)
#     796                                            ismath=ismath, mtext=mtext)
#     797
# --> 798         gc.restore()
#     799         renderer.close_group('text')
#     800         self.stale = False
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     247                 self.tick1line.draw(renderer)
#     248             if self.tick2On:
# --> 249                 self.tick2line.draw(renderer)
#     250
#     251         if self.label1On:
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     800                 if marker.get_marker() != ',':
#     801                     # Don't scale for pixels, and don't stroke them
# --> 802                     marker_trans = marker_trans.scale(w)
#     803                 else:
#     804                     gc.set_linewidth(0)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in scale(self, sx, sy)
#    1965             np.float_)
#    1966         self._mtx = np.dot(scale_mtx, self._mtx)
# -> 1967         self.invalidate()
#    1968         return self
#    1969
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in invalidate(self)
#     134         if self.is_affine:
#     135             value = self.INVALID_AFFINE
# --> 136         return self._invalidate_internal(value, invalidating_node=self)
#     137
#     138     def _invalidate_internal(self, value, invalidating_node):
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     156             self._invalid = value
#     157
# --> 158             for parent in list(six.itervalues(self._parents)):
#     159                 parent._invalidate_internal(value=value,
#     160                                             invalidating_node=self)
#
# /Users/rac/anaconda/lib/python3.5/weakref.py in values(self)
#     219
#     220     def values(self):
# --> 221         with _IterationGuard(self):
#     222             for wr in self.data.values():
#     223                 obj = wr()
#
# /Users/rac/anaconda/lib/python3.5/_weakrefset.py in __init__(self, weakcontainer)
#      14     # This technique should be relatively thread-safe (since sets are).
#      15
# ---> 16     def __init__(self, weakcontainer):
#      17         # Don't create cycles
#      18         self.weakcontainer = ref(weakcontainer)
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1104         renderer.open_group(__name__)
#    1105
# -> 1106         ticks_to_draw = self._update_ticks(renderer)
#    1107         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1108                                                                 renderer)
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1040             tick.update_position(loc)
#    1041             tick.set_label1(label)
# -> 1042             tick.set_label2(label)
#    1043             ticks_to_draw.append(tick)
#    1044
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in set_label2(self, s)
#     275         """
#     276         self.label2.set_text(s)
# --> 277         self.stale = True
#     278
#     279     def _set_artist_props(self, a):
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in stale(self, val)
#     265
#     266         if val and self.stale_callback is not None:
# --> 267             self.stale_callback(self, val)
#     268
#     269     def get_window_extent(self, renderer):
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in _stale_axes_callback(self, val)
#      72 def _stale_axes_callback(self, val):
#      73     if self.axes:
# ---> 74         self.axes.stale = val
#      75
#      76
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in stale(self, val)
#     265
#     266         if val and self.stale_callback is not None:
# --> 267             self.stale_callback(self, val)
#     268
#     269     def get_window_extent(self, renderer):
#
# /Users/rac/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in _stale_figure_callback(self, val)
#      52
#      53
# ---> 54 def _stale_figure_callback(self, val):
#      55     if self.figure:
#      56         self.figure.stale = val
#
# KeyboardInterrupt:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
