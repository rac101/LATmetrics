# %% [markdown]
# # FFT of LAT trigger rate history
#
# ### Robert Cameron, April 2016

# %%
from astropy.table import Table, Column
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import datetime as dt
# %matplotlib inline
plt.rc('figure', figsize = [12, 10])
plt.rc('font', size = 16)

# %%
# read regular ASCII tabular files of data

file1 = "/Users/rac/Documents/GLAST/ISOC/LATmetrics/Triggers/trigrate.jana"
tj = Table.read(file1, format = 'ascii')
tr = tj['col21']
avg = sum(tr)/len(tr)
tr0 = tr - avg

# %%
plt.plot(tr)

# %%
plt.plot(tr0)

# %%
rate = 1.0

#ps = np.abs(np.fft.fft(tr))**2
#freqs = np.fft.fftfreq(tr.size, time_step)
#idx = np.argsort(freqs)
#plt.plot(freqs[idx], ps[idx])


p = np.abs(np.fft.rfft(tr))**2
f = np.linspace(0, rate/2, len(p))
per = 1/f
plt.plot(per, p)

# %%
fr[0:9]
# Out:
# array([ 5382672.70000000    +0.j        ,
#          -17139.44134661-73006.66668143j,
#          -32263.65894714-27203.59270587j,
#          -15790.15720889 +3707.84267985j,
#           -9270.22502653 +6573.38948091j,
#           -7330.32166609 +9824.0741834j ,
#          -10628.56621165  -654.57704354j,
#          -12028.11220807-14362.74690813j,   -27053.89970946 +2296.61745327j])

# %%
n_bins = 100
#n, bins, patches = plt.hist(lt1, n_bins, normed=1, histtype='step', cumulative=True)
plt.hist(lt1, n_bins, normed=1, histtype='step', cumulative=True, color=c1, label=lab1)
plt.hist(lt2, n_bins, normed=1, histtype='step', cumulative=True, color=c2, label=lab2)

plt.grid(True)
plt.ylim(0, 1.05)
plt.title('Run Processing Time (hours): '+type)
plt.legend(loc='upper left')

plt.show()

# %%
plt.xscale("log")
plt.hist(t1, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab1, color=c1)
plt.hist(t2, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab2, color=c2)
plt.legend(loc='lower right')
plt.ylim(0, 1.05)
plt.yticks( np.arange(21)/20 )
plt.grid(b=True, which='both', color='0.65',linestyle='-')
plt.title('Run Processing Time (hours): '+type)
plt.ylabel('Normalized Cumulative Distribution')
plt.show()

# %%
plt.xscale("log")
plt.hist(t3, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab3, color=c3)
plt.hist(t1, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab1, color=c1)
plt.hist(t2, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab2, color=c2)

plt.legend(loc='lower right')
plt.ylim(0, 1.05)
plt.yticks( np.arange(21)/20 )
plt.grid(b=True, which='both', color='0.65',linestyle='-')
plt.title('Run Processing Time (hours): '+type)
plt.ylabel('Normalized Cumulative Distribution')
plt.show()

# %%
plt.xscale("log")
plt.hist(t3, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab3, color=c3)
plt.hist(t2, bins = np.logspace(0, 2, 1000), normed=1, histtype='step', cumulative=True, label=lab2, color=c2)

plt.legend(loc='lower right')
plt.ylim(0, 1.05)
plt.yticks( np.arange(21)/20 )
plt.grid(b=True, which='both', color='0.65',linestyle='-')
plt.title('Run Processing Time (hours): '+type)
plt.ylabel('Normalized Cumulative Distribution')
plt.show()
