# %% [markdown]
# # Fermi Orbit Altitude History
#
# ### Robert Cameron, March 2016

# %%
from astropy.table import Table, Column
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import datetime as dt
# %matplotlib inline
plt.rc('figure', figsize = [13, 8])
plt.rc('font', size = 18)

# %%
# read regular ASCII tabular file of Fermi orbit history
file = "/Users/rac/Documents/GLAST/ISOC/LATmetrics/orbit/orbit-history.txt"
t = Table.read(file, format='ascii')
tt = t[1:]
y = tt['Year']
alt = tt['Alt']
plt.ylabel('Altitude (km)')
plt.ylim([530,555])
plt.xlim([2008,2018])
#plt.tick_params(axis = 'both', which = 'major')
#plt.tick_params(axis = 'both', which = 'minor')
plt.minorticks_on()
plt.grid(which='major')
plt.ticklabel_format(useOffset=False)
plt.plot(y, alt, '', lw=2)
plt.savefig('/Users/rac/Documents/GLAST/ISOC/LATmetrics/orbit/alt2017.png')

# %%
plt.savefig('/Users/rac/Documents/GLAST/ISOC/LATmetrics/orbit/alt2017.png')
