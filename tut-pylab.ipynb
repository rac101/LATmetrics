# %% [markdown]
# # Simple Notebook

# %% [markdown]
# This is some **markdown** text with $LaTeX$.

# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = linspace(0, 10)
y = sin(x)

pylab.xlim(-1, 19)
pylab.ylim(-1.2, 1.2)

pylab.xlabel('This is x!')
pylab.ylabel('This is y!', color='b')
pylab.title(r'$\sin(2 \pi x)$')  # the `r` before the string indicates a "raw string"
pylab.text(10,0.8,"Here's some text",color='r',fontsize='x-large')
plot (x,y)

# %%
 time, sberr, dberr, toterr = np.loadtxt("memerr.txt", unpack=True)

# %%
plot (time,toterr)

# %%
plot (time, dberr, 'bo-')

# %%
plot (time, sberr, 'gD')

# %%
x = np.linspace(0, 20, 100)
y1 = np.sin(x)
y2 = np.cos(x)

pylab.plot(x, y1, '-b', label='sine')
pylab.plot(x, y2, '-r', label='cosine')
pylab.legend(loc='upper right')
pylab.ylim(-1.5, 2.0)
# Out:
# (-1.5, 2.0)

# %%
tle = !tail -2 /Users/rc/Documents/GLAST/FGST-TLE.txt

# %%
tle
# Out:
# ['tail: /Users/rc/Documents/GLAST/FGST-TLE.txt: No such file or directory']

# %%
tle[0]
# Out:
# 'tail: /Users/rc/Documents/GLAST/FGST-TLE.txt: No such file or directory'

# %%
tle[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-f8aaa7470c4e> in <module>()
# ----> 1 tle[1]
#
# IndexError: list index out of range

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)

plt.show()
