# %% [markdown]
# # Simple Notebook

# %% [markdown]
# This is some **markdown** text with $LaTeX$.

# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = linspace(0, 10)
y = sin(x)

pylab.xlim(-1, 19)
pylab.ylim(-1.2, 1.2)

pylab.xlabel('This is x!')
pylab.ylabel('This is y!', color='b')
pylab.title(r'$\sin(2 \pi x)$')  # the `r` before the string indicates a "raw string"
pylab.text(10,0.8,"Here's some text",color='r',fontsize='x-large')
plot (x,y)

# %%
 time, sberr, dberr, toterr = np.loadtxt("memerr.txt", unpack=True)

# %%
plot (time,toterr)

# %%
plot (time, dberr, 'bo-')

# %%
plot (time, sberr, 'gD')

# %%
x = np.linspace(0, 20, 100)
y1 = np.sin(x)
y2 = np.cos(x)

pylab.plot(x, y1, '-b', label='sine')
pylab.plot(x, y2, '-r', label='cosine')
pylab.legend(loc='upper right')
pylab.ylim(-1.5, 2.0)
# Out:
# (-1.5, 2.0)

# %%
pylab.plot?

# %%
tle = !tail -2 /Users/rc/Documents/GLAST/FGST-TLE.txt

# %%
tle
# Out:
# ['1 33053U 08029A   15250.91174385  .00000989  00000-0  41644-4 0  9993',
#  '2 33053  25.5829  93.4313 0012695 348.3167  11.7072 15.10087259399169']

# %%
tle[0]
# Out:
# '1 33053U 08029A   15250.91174385  .00000989  00000-0  41644-4 0  9993'

# %%
tle[1]
# Out:
# '2 33053  25.5829  93.4313 0012695 348.3167  11.7072 15.10087259399169'
